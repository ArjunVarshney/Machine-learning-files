# %% [markdown]
# ## Importing Libraries

# %%
# !pip install fasteda
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from fasteda import fast_eda
# Out:
# Collecting fasteda
#   Downloading fasteda-1.0.1.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fasteda) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fasteda) (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from fasteda) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from fasteda) (0.12.2)
# Requirement already satisfied: missingno in /usr/local/lib/python3.10/dist-packages (from fasteda) (0.5.2)
# Collecting colorama (from fasteda)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->fasteda) (2.8.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from missingno->fasteda) (1.11.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fasteda) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->fasteda) (1.16.0)
# Building wheels for collected packages: fasteda
#   Building wheel for fasteda (setup.py) ... done
#   Created wheel for fasteda: filename=fasteda-1.0.1-py3-none-any.whl size=4723 sha256=aceec715562ff3e9f31073bf6f9c39d4bcb0597c96f6d9a6a0f922fd409870cb
#   Stored in directory: /root/.cache/pip/wheels/ed/08/72/0d0ec0d3927d227b38ce9542ec3fa6b975c2e17ad0d046dcee
# Successfully built fasteda
# Installing collected packages: colorama, fasteda
# Successfully installed colorama-0.4.6 fasteda-1.0.1

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/gld_price_data.csv");
df
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %% [markdown]
# ### About the dataset:

# %%
df.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
fast_eda(df)
# Out:
# DataFrame Head:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# DataFrame Tail:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033
# ----------------------------------------------------------------------------------------------------
# Missing values:
# <style type="text/css">
# </style>
# <table id="T_8605a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8605a_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# Shape of DataFrame:
#
# (2290, 6)
#
# ----------------------------------------------------------------------------------------------------
# DataFrame Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB
# ----------------------------------------------------------------------------------------------------
# Describe DataFrame:
# <style type="text/css">
# #T_a5a3c_row0_col0, #T_a5a3c_row1_col0, #T_a5a3c_row2_col0, #T_a5a3c_row3_col0, #T_a5a3c_row4_col0, #T_a5a3c_row4_col1, #T_a5a3c_row4_col2, #T_a5a3c_row4_col3, #T_a5a3c_row4_col4, #T_a5a3c_row4_col5, #T_a5a3c_row4_col6, #T_a5a3c_row4_col7, #T_a5a3c_row4_col8 {
#   background-color: #9e0142;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row0_col1, #T_a5a3c_row0_col2, #T_a5a3c_row0_col3, #T_a5a3c_row0_col4, #T_a5a3c_row0_col5, #T_a5a3c_row0_col6, #T_a5a3c_row0_col7, #T_a5a3c_row0_col8 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row0_col9, #T_a5a3c_row1_col9, #T_a5a3c_row2_col9, #T_a5a3c_row2_col10, #T_a5a3c_row3_col9, #T_a5a3c_row3_col10 {
#   color: #00ff00;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_a5a3c_row0_col10, #T_a5a3c_row1_col10, #T_a5a3c_row4_col9, #T_a5a3c_row4_col10 {
#   color: #ff0000;
#   background-color: #000000;
#   font-weight: bold;
# }
# #T_a5a3c_row1_col1 {
#   background-color: #c52c4b;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row1_col2, #T_a5a3c_row1_col6 {
#   background-color: #c72e4c;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row1_col3 {
#   background-color: #b61b48;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row1_col4 {
#   background-color: #d63f4f;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row1_col5 {
#   background-color: #cd364d;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row1_col7, #T_a5a3c_row1_col8 {
#   background-color: #c1274a;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row2_col1, #T_a5a3c_row2_col7, #T_a5a3c_row3_col8 {
#   background-color: #a70b44;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row2_col2, #T_a5a3c_row2_col6 {
#   background-color: #a90d45;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row2_col3 {
#   background-color: #b11747;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row2_col4, #T_a5a3c_row2_col5, #T_a5a3c_row3_col1, #T_a5a3c_row3_col2, #T_a5a3c_row3_col4, #T_a5a3c_row3_col5, #T_a5a3c_row3_col6, #T_a5a3c_row3_col7 {
#   background-color: #a20643;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row2_col8 {
#   background-color: #b41947;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# #T_a5a3c_row3_col3 {
#   background-color: #a40844;
#   color: #f1f1f1;
#   font-weight: bold;
# }
# </style>
# <table id="T_a5a3c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5a3c_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a5a3c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a5a3c_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_a5a3c_level0_col3" class="col_heading level0 col3" >std</th>
#       <th id="T_a5a3c_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_a5a3c_level0_col5" class="col_heading level0 col5" >25%</th>
#       <th id="T_a5a3c_level0_col6" class="col_heading level0 col6" >50%</th>
#       <th id="T_a5a3c_level0_col7" class="col_heading level0 col7" >75%</th>
#       <th id="T_a5a3c_level0_col8" class="col_heading level0 col8" >max</th>
#       <th id="T_a5a3c_level0_col9" class="col_heading level0 col9" >skewness</th>
#       <th id="T_a5a3c_level0_col10" class="col_heading level0 col10" >kurtosis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5a3c_level0_row0" class="row_heading level0 row0" >SPX</th>
#       <td id="T_a5a3c_row0_col0" class="data row0 col0" >2290</td>
#       <td id="T_a5a3c_row0_col1" class="data row0 col1" >1654.316</td>
#       <td id="T_a5a3c_row0_col2" class="data row0 col2" >1551.435</td>
#       <td id="T_a5a3c_row0_col3" class="data row0 col3" >519.112</td>
#       <td id="T_a5a3c_row0_col4" class="data row0 col4" >676.53</td>
#       <td id="T_a5a3c_row0_col5" class="data row0 col5" >1239.875</td>
#       <td id="T_a5a3c_row0_col6" class="data row0 col6" >1551.435</td>
#       <td id="T_a5a3c_row0_col7" class="data row0 col7" >2073.01</td>
#       <td id="T_a5a3c_row0_col8" class="data row0 col8" >2872.87</td>
#       <td id="T_a5a3c_row0_col9" class="data row0 col9" >0.300165</td>
#       <td id="T_a5a3c_row0_col10" class="data row0 col10" >-0.951167</td>
#     </tr>
#     <tr>
#       <th id="T_a5a3c_level0_row1" class="row_heading level0 row1" >GLD</th>
#       <td id="T_a5a3c_row1_col0" class="data row1 col0" >2290</td>
#       <td id="T_a5a3c_row1_col1" class="data row1 col1" >122.733</td>
#       <td id="T_a5a3c_row1_col2" class="data row1 col2" >120.58</td>
#       <td id="T_a5a3c_row1_col3" class="data row1 col3" >23.283</td>
#       <td id="T_a5a3c_row1_col4" class="data row1 col4" >70</td>
#       <td id="T_a5a3c_row1_col5" class="data row1 col5" >109.725</td>
#       <td id="T_a5a3c_row1_col6" class="data row1 col6" >120.58</td>
#       <td id="T_a5a3c_row1_col7" class="data row1 col7" >132.84</td>
#       <td id="T_a5a3c_row1_col8" class="data row1 col8" >184.59</td>
#       <td id="T_a5a3c_row1_col9" class="data row1 col9" >0.333919</td>
#       <td id="T_a5a3c_row1_col10" class="data row1 col10" >-0.277099</td>
#     </tr>
#     <tr>
#       <th id="T_a5a3c_level0_row2" class="row_heading level0 row2" >USO</th>
#       <td id="T_a5a3c_row2_col0" class="data row2 col0" >2290</td>
#       <td id="T_a5a3c_row2_col1" class="data row2 col1" >31.842</td>
#       <td id="T_a5a3c_row2_col2" class="data row2 col2" >33.87</td>
#       <td id="T_a5a3c_row2_col3" class="data row2 col3" >19.524</td>
#       <td id="T_a5a3c_row2_col4" class="data row2 col4" >7.96</td>
#       <td id="T_a5a3c_row2_col5" class="data row2 col5" >14.38</td>
#       <td id="T_a5a3c_row2_col6" class="data row2 col6" >33.87</td>
#       <td id="T_a5a3c_row2_col7" class="data row2 col7" >37.828</td>
#       <td id="T_a5a3c_row2_col8" class="data row2 col8" >117.48</td>
#       <td id="T_a5a3c_row2_col9" class="data row2 col9" >1.698218</td>
#       <td id="T_a5a3c_row2_col10" class="data row2 col10" >4.217878</td>
#     </tr>
#     <tr>
#       <th id="T_a5a3c_level0_row3" class="row_heading level0 row3" >SLV</th>
#       <td id="T_a5a3c_row3_col0" class="data row3 col0" >2290</td>
#       <td id="T_a5a3c_row3_col1" class="data row3 col1" >20.085</td>
#       <td id="T_a5a3c_row3_col2" class="data row3 col2" >17.268</td>
#       <td id="T_a5a3c_row3_col3" class="data row3 col3" >7.093</td>
#       <td id="T_a5a3c_row3_col4" class="data row3 col4" >8.85</td>
#       <td id="T_a5a3c_row3_col5" class="data row3 col5" >15.57</td>
#       <td id="T_a5a3c_row3_col6" class="data row3 col6" >17.268</td>
#       <td id="T_a5a3c_row3_col7" class="data row3 col7" >22.882</td>
#       <td id="T_a5a3c_row3_col8" class="data row3 col8" >47.26</td>
#       <td id="T_a5a3c_row3_col9" class="data row3 col9" >1.152885</td>
#       <td id="T_a5a3c_row3_col10" class="data row3 col10" >0.466502</td>
#     </tr>
#     <tr>
#       <th id="T_a5a3c_level0_row4" class="row_heading level0 row4" >EUR/USD</th>
#       <td id="T_a5a3c_row4_col0" class="data row4 col0" >2290</td>
#       <td id="T_a5a3c_row4_col1" class="data row4 col1" >1.284</td>
#       <td id="T_a5a3c_row4_col2" class="data row4 col2" >1.303</td>
#       <td id="T_a5a3c_row4_col3" class="data row4 col3" >0.132</td>
#       <td id="T_a5a3c_row4_col4" class="data row4 col4" >1.039</td>
#       <td id="T_a5a3c_row4_col5" class="data row4 col5" >1.171</td>
#       <td id="T_a5a3c_row4_col6" class="data row4 col6" >1.303</td>
#       <td id="T_a5a3c_row4_col7" class="data row4 col7" >1.37</td>
#       <td id="T_a5a3c_row4_col8" class="data row4 col8" >1.599</td>
#       <td id="T_a5a3c_row4_col9" class="data row4 col9" >-0.005289</td>
#       <td id="T_a5a3c_row4_col10" class="data row4 col10" >-0.743749</td>
#     </tr>
#   </tbody>
# </table>
# ----------------------------------------------------------------------------------------------------
# DataFrame Correlation:
# /usr/local/lib/python3.10/dist-packages/fasteda/__init__.py:124: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = "Spectral", linewidths = 2, linecolor = "#000000", fmt='.3f')
# ----------------------------------------------------------------------------------------------------
# DataFrame Pairplot:
# ----------------------------------------------------------------------------------------------------
# Histogram(s) & Boxplot(s):

# %%
corr = df.corr()
# Out:
# <ipython-input-9-45893e33df67>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# Checking the distribution of GLD
sns.distplot(df["GLD"])
# Out:
# <ipython-input-11-9ee019bb9497>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["GLD"])
# <Axes: xlabel='GLD', ylabel='Density'>

# %% [markdown]
# ## Outlier Removal

# %%
for column in df.iloc[:,1:]:
  plt.figure(figsize=(17,1))
  sns.boxplot(data=df, x=column)

# %%
for col in df.iloc[:,1:]:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3-q1
  lowerExtreme = q1 - 1.5*iqr
  upperExtreme = q3 + 1.5*iqr
  df = df[(df[col] <= upperExtreme) & (df[col] >= lowerExtreme)]
df.shape
# Out:
# (1909, 6)

# %% [markdown]
# ## Splitting the Features and Target

# %%
x = df.drop(columns=["Date","GLD"], axis=1)
y=df["GLD"]

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x = scaler.fit_transform(x)
x
# Out:
# array([[-0.56741281,  3.68784934, -0.4927267 ,  1.87072251],
#        [-0.6033    ,  3.61514805, -0.48962985,  1.86158055],
#        [-0.64059989,  3.59091454, -0.53666623,  1.87164172],
#        ...,
#        [ 1.85370797, -0.97206397, -0.55486137, -0.53883564],
#        [ 1.86682852, -0.97440917, -0.58970313, -0.52742908],
#        [ 1.85874439, -0.9723923 , -0.61018234, -0.62006036]])

# %% [markdown]
# ## Splitting the Training and testing data

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20);
x_train.shape, y_test.shape
# Out:
# ((1527, 4), (382,))

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=100)

# %%
# training the model
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Model Evaluation

# %%
# test data prediction
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.9880322764805908

# %% [markdown]
# ## Comparing the actual and predicted values

# %%
plt.figure();
plt.plot(y_test,"bo")
plt.plot(y_pred, "ro")
plt.show()

# %%
input = {"SPX": [1447.16],
"USO":[78.47],
"SLV":[15.18],
"EUR/USD": [1.4716]}
input_pd = pd.DataFrame(input)
input_pd = scaler.transform(input_pd)
regressor.predict(input_pd)
# Out:
# array([87.39899817])

# %%
import pickle

pickle.dump(scaler, open("scaler.pkl", "wb"))
pickle.dump(regressor, open("model.pkl", "wb"))
